# %% [markdown]
# #Data Types and Structures Questions
#
# 1.	What are data structures, and why are they important?
#
#   Ans: Data structures are nothing but containers for different kinds of data. Python has four types of Data Structures like lists, sets, tuples and dictionaries.Data Structures are use to store and to process the data in an efficient way which helps easy to access, manipulate the data.
#
# 2.	Explain the difference between mutable and immutable data types with examples?
#   Ans:Mutable Objects can change its value without changing memory address, Immutable objects cant be changes after initialized, we can change the value, in the same way memory address will change so that original data will be deleted .
# Ex: lis=[1,2,3,4]
# Lis[0]=5 # we can add an item to the list directly
# Tup=(1,2,3,4)
# Tup[0]=5 #gives an error, because tuple is imutable type
#
# 3.	What are the main differences between lists and tuples in Python?
#
#   Ans:1)	Lists are mutable ------Tuples are immutable
#   2)	Lists not a hashable type -----Tuples are hashable
#   3)	Lists need more memory because of manipulations it over allocates memory--- Tuple need less memory
#   4)	Lists are slow – Tuples process is fast when comparing to lists
#   5)	Lists are easy to modify --- Modification of a tuple is little tricky
#   6)	List are useful to contain the date which changes rapidly like marks, weather temp.---Tuples are useful in handling constant type of data like name, id.
#   7)	List has more no.of built-in functions to manipulate access the data ----Tuples having less no.of built-in functions when comparing to a list.
#
# 4.	Describe how dictionaries store data?
# -Dictionaries stores the data in the form of Keys and Values where keys are Immutable type. It does not support integer indexing, we should access the data by the keys. Ex: d[‘key_name’]
#
# 5.	Why might you use a set instead of a list in Python?
# Set is useful when we need unique/distinct type values.
#
# 6.	What is a string in Python, and how is it different from a list?
#
#   Ans:String is nothing but a data type which holds only sequence of characters. List is a data structure which can contain multiple data type values.
#
# 7.	How do tuples ensure data integrity in Python?
#
#   Ans:Tuple are immutable and initialize by using paranthesis () means it holding the values as arguments which are immutable type, this special characteristic that made tuple are powerful data structure in ensuring the data integrity.
#
# 8.	What is a hash table, and how does it relate to dictionaries in Python?
#
#   Ans: Hash table is a Data structure type that stores the data in the form of keys and values, where keys are generated by hash function. It follows hash mapping which means a piece of code will have a fixed length value. Dictionaries following the same hash type mapping.
#   Dictionaries are useful in maintaining  cryptographic data such as user_id and password.
#  Ex: dict={“user1”:”pass1”, “user2”:”pass2”,  , , , , ,}
#
# 9.	Can lists contain different data types in Python?
#
#   Ans:-Yes, List can contain different data types . Ex: list1=[‘name’, 1,1.2,’True’]
#
# 10.	Explain why strings are immutable in Python?
#
#   Ans:-Immutable means it cant be changed once after created.
#   Ex:  name_1 = "Aarun"
#               name_1[0] = 'T' #cant be modified by simply assigning with index
#   Output: TypeError: 'str' object does not support item assignment
#   Explanation: We cannot update the string after declaring it means once an immutable the objects instantiated, its value cannot be changed.
#
# 11.	What advantages do dictionaries offer over lists for certain tasks?
#
#   Ans:-1)Lists takes more time to perform searching tasks like – Dictionaries are quick because of key pairs.
#   2)Lists can contain duplicate values with different indices- Dictionaries holds unique keys nd duplicate values which means dictionaries implicitly follows uniqueness and duplicates at the same time .
#   3)List doesn’t support hashable mapping ---- Dictionaries follows hashable mappings
#   4)list contains mutable data which can rapidly changes---- Dictionaries are immutable type.
#
# 12.	Describe a scenario where using a tuple would be preferable over a list?
#
#
#   Ans:Tuples are immutable so we can store constant data like name, adhaar no, date of birth
#   Lists are mutable which is not ideal to store data which doesn’t need changes.
#
#   Tuples are hashable so that we can use a tuple in dictionaries as keys
#   Lists are not hashable
#
#   Tuples are usually contained heterogeneous type
#   Lists are usually contained homogeneous type data
#
# 13.	How do sets handle duplicate values in Python?
#
#   Ans:-Set is an unordered collection of data structures which contains unique values only. Even if you enter duplicates while initializing, it automatically deletes the duplicate values while storing/saving.
#   Ex: a={1,2,3,4,5,6,2,3,1,’a’}
#   It saves only unique values i.e a={1,2,3,4,5,6,’a’}
#
# 14.	How does the “in” keyword work differently for lists and dictionaries?
#
#   Ans:-“In” is a keyword which is used to search the elements.
#   List can be traversed by the “in” keyword , it checks the values directly.
#   Whereas in dictionaries the “in’ keyword searches the key elements not values. Here keys can be act s indices of values.
#
#
# 15.	Can you modify the elements of a tuple? Explain why or why not?
#
#   Ans:- Tuples are immutable, so once a tuple is created, you can neither change the values of the elements nor add/remove elements without creating a new tuple.
#   Even if we update using some other ways like by converting into list , the id will change. So we cant modify a tuple.
#
# 16.	What is a nested dictionary, and give an example of its use case?
#
#   Ans:-Dictionary contains another dictionary as values.
#   Let’s assume two dictionaries which stores teacher and student records.
#   Class will have a teacher and students.
#   Ex: class_dict={“class_name”:”first”, teacher_name:{teachers1.name:”pushpa”,teacher2:”raju”…},student_name:{stu-name:”aarya”,stu_name2:”jovi”…}
#
# 17.	Describe the time complexity of accessing elements in a dictionary?
#
#   Ans:- The time complexity of retrieving a value by its key in a dictionary is O(1). This is because dictionaries use a hash table internally which allows constant time lookup.
#
# 18.	In what situations are lists preferred over dictionaries?
#
#   Ans:-While we are using mutable type data like marks, dates, time, address, location and etc…
#   While we’re using homogeneous data which doesn’t need any code pair.
#   To perform manipulation functions like add, insert, reverse, sort…etc
#
# 19.	Why are dictionaries considered unordered, and how does that affect data retrieval?
#
#   Ans:-Dictionaries are accessed by using keys, we can not perform sorting directly on values. So dictionaries doesn’t follow either ascending or descending order in retrieving values.
#   So As per keys order only we can access the data. So it is considered as unordered.
#
# 20.	Explain the difference between a list and a dictionary in terms of data retrieval?
#
#   Ans:-Keys referred as indices in dictionaries.
#   List only supports integer indexing.
#   2)In dictionaries we can use, Keys() functions and Values() function to retrieve the data
#   List uses only index

# %%
#1.Write a code to create a string with your name and print it?
name=input("enter your name")
print("Hello! " ,name, "how are you")

#2.Write a code to find the length of the string "Hello World"?
print(len("Hello World"))

#3.Write a code to slice the first 3 characters from the string "Python Programming"
print("Python Programming"[0:3])

#4.Write a code to convert the string "hello" to uppercase
str="hello"
print(str.upper())

#5.Write a code to replace the word "apple" with "orange" in the string "I like apple"
str1="I like apple"
print(str1.replace("apple","orange"))

#6.Write a code to create a list with numbers 1 to 5 and print it
list=[1,2,3,4,5]
print(list)

#7.Write a code to append the number 10 to the list [1, 2, 3, 4]?
list1=[1,2,3,4]
list1.append(10)
print(list1)

#8.Write a code to remove the number 3 from the list [1, 2, 3, 4, 5]
list2=[1,2,3,4,5]
list2.remove(3)
print(list2)

#9.Write a code to access the second element in the list ['a', 'b', 'c', 'd']
list3=['a','b','c','d']
print(list3[1])

#10.Write a code to reverse the list [10, 20, 30, 40, 50]
list4=[10,20,30,40,50]
list4.reverse()
print(list4)

#11. Write a code to create a tuple with the elements 10, 20, 30 and print it.
tup=(10,20,30)
print(tup)

#12. Write a code to access the first element of the tuple ('apple', 'banana', 'cherry').
my_tuple = ('apple', 'banana', 'cherry')
print(my_tuple[0])

#13. Write a code to count how many times the number 2 appears in the tuple (1, 2, 3, 2, 4, 2)
my_tuple1 = (1, 2, 3, 2, 4, 2)
print(my_tuple1.count(2))

#14. Write a code to find the index of the element "cat" in the tuple ('dog', 'cat', 'rabbit')
my_tuple2 = ('dog', 'cat', 'rabbit')
print(my_tuple2.index('cat'))

#15. Write a code to check if the element "banana" is in the tuple ('apple', 'orange', 'banana')
my_tuple3 = ('apple', 'orange', 'banana')
print('banana' in my_tuple3)

#16. Write a code to create a set with the elements 1, 2, 3, 4, 5 and print it.
s={1,2,3,4,5}
print(s)


#17. Write a code to add the element 6 to the set {1, 2, 3, 4}.
s1={1,2,3,4}
s1.add(6)
print(s1)

#18. Write a code to create a tuple with the elements 10, 20, 30 and print it.
tup=(10,20,30)
print(tup)

#19. Write a code to access the first element of the tuple ('apple', 'banana', 'cherry')
my_tuple = ('apple', 'banana', 'cherry')
print(my_tuple[0])

#20. Write a code to count how many times the number 2 appears in the tuple (1, 2, 3, 2, 4, 2)
my_tuple1 = (1, 2, 3, 2, 4, 2)
print(my_tuple1.count(2))

#21. Write a code to find the index of the element "cat" in the tuple ('dog', 'cat', 'rabbit')
my_tuple2 = ('dog', 'cat', 'rabbit')
print(my_tuple2.index('cat'))

#22.Write a code to check if the element "banana" is in the tuple ('apple', 'orange', 'banana'
my_tuple3 = ('apple', 'orange', 'banana')
print('banana' in my_tuple3)

23. Write a code to create a set with the elements 1, 2, 3, 4, 5 and print it.
s={1,2,3,4,5}
print(s)

24. Write a code to add the element 6 to the set {1, 2, 3, 4}
s1={1,2,3,4}
s1.add(6)
print(s1)
# Out:
# {1, 2, 3, 4, 6}
